# %%
import numpy as np
import pandas as pd

# %%
flats = pd.read_csv('flats_cleaned.csv')
houses = pd.read_csv('house_cleaned.csv')

# %%
df = pd.concat([flats,houses],ignore_index=True)

# %%
df = df.sample(df.shape[0],ignore_index=True)

# %%
df.head()
# Out:
#                                       property_name property_type  \
# 0           10 Bedroom House for sale in Sohna Road         house
# 1                   4 BHK Flat in Sector 66 Gurgaon          flat
# 2           9 Bedroom House for sale in DLF Phase 2         house
# 3          10 Bedroom House for sale in DLF Phase 3         house
# 4  3 Bedroom House for sale in Laxman Vihar Phase 2         house
#
#                           society  price  price_per_sqft    area  \
# 0                     independent   0.95          8920.0  1065.0
# 1  emaar mgf palm terraces select   3.40         14107.0  2410.0
# 2          dlf city plots phase 2  10.75         29861.0  3600.0
# 3                     independent   4.50         33333.0  1350.0
# 4                     independent   0.67         88157.0    76.0
#
#                                         areaWithType  bedRoom  bathroom  \
# 0                        Plot area 1065(98.94 sq.m.)       10        10
# 1  Super Built up area 2410(223.9 sq.m.)Built Up ...        4         4
# 2                        Plot area 400(334.45 sq.m.)        9         9
# 3  Plot area 163(136.29 sq.m.)Built Up area: 160 ...       10         8
# 4                           Plot area 76(7.06 sq.m.)        3         3
#
#   balcony                      additionalRoom  \
# 0      3+                       not available
# 1      3+                        servant room
# 2      3+  servant room,pooja room,store room
# 3      3+             store room,servant room
# 4       2                              others
#
#                                              address  floorNum      facing  \
# 0          Rbsm Colony, Sohna Road, Gurgaon, Haryana       3.0         NaN
# 1  Palm Terraces Select, Sector 66, Golf Course E...       2.0  North-East
# 2                      DLF Phase 2, Gurgaon, Haryana       3.0  South-West
# 3         Dlf Phase 3, DLF Phase 3, Gurgaon, Haryana       4.0        East
# 4             Laxman Vihar Phase 2, Gurgaon, Haryana       2.0       South
#
#      agePossession                                    nearbyLocations  \
# 0  0 to 1 Year Old  ['Rajiv Chowk Mosque', 'Standard chartered ATM...
# 1  1 to 5 Year Old  ['Sector 55/56 Metro Station', 'Omaxe Gurgaon ...
# 2     10+ Year Old  ['Vodafone belvedere towers metro station', 'D...
# 3  1 to 5 Year Old  ['Dlf phase 3 metro station', 'Micromax moulsa...
# 4  1 to 5 Year Old  ['Chintapurni Mandir', 'Sheetla Mata Mandir', ...
#
#                                          description  \
# 0  Interested to sell independent house/villa con...
# 1  Emaar palm terraces select one of the best res...
# 2  This is located in dlf phase 2 very near from ...
# 3  Dlf phase 3 very prime location , this buildin...
# 4  Near by main road near by railways station nea...
#
#                                       furnishDetails  \
# 0  ['1 Bed', '1 Wardrobe', '1 Fan', '1 Light', 'N...
# 1  ['4 Wardrobe', '9 Fan', '1 Exhaust Fan', '6 Ge...
# 2  ['5 Fan', '1 Exhaust Fan', '3 Light', 'No AC',...
# 3  ['1 Water Purifier', '10 Fan', '1 Exhaust Fan'...
# 4                                                NaN
#
#                                             features  \
# 0                                                NaN
# 1  ['Centrally Air Conditioned', 'Water purifier'...
# 2  ['Security / Fire Alarm', 'Private Garden / Te...
# 3  ['Feng Shui / Vaastu Compliant', 'Maintenance ...
# 4                                ['Visitor Parking']
#
#                                               rating
# 0                                                NaN
# 1  ['Green Area5 out of 5', 'Construction4 out of...
# 2  ['Environment5 out of 5', 'Lifestyle5 out of 5...
# 3  ['Environment4 out of 5', 'Safety4 out of 5', ...
# 4                                                NaN

# %%
df.to_csv('gurgaon_properties.csv',index=False)
